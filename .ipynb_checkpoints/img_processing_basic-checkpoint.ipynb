# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
red = arr[:,:,0]

# %%
plt.imshow(red)

# %%
work = arr.copy()
work[:,:,[1,2]]=0

# %%
plt.imshow(work)
